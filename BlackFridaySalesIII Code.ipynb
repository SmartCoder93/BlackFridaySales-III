# %%
import pandas as pd
import numpy as np

# %%
BFTrain=pd.read_csv("/Users/shankarraja/Downloads/Data Science/Ampersand Academy/BlackFriday/Train.csv")

# %%
BFTest=pd.read_csv("/Users/shankarraja/Downloads/Data Science/Ampersand Academy/BlackFriday/Test.csv")

# %%
BFTrain
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
BFTest
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
BFTrain.shape
# Out:
# (550068, 12)

# %%
BFTrain.apply(lambda x: sum(x.isnull()))
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
BFTrain.Product_Category_2.mean()
# Out:
# 9.842329251122386

# %%
BFTrain.Product_Category_3.mean()
# Out:
# 12.668243206790512

# %%
BFTrain["Product_Category_2"]=BFTrain.Product_Category_2.fillna(BFTrain.Product_Category_2.mean())

# %%
BFTrain["Product_Category_3"]=BFTrain.Product_Category_3.fillna(BFTrain.Product_Category_3.mean())

# %%
BFTrain.apply(lambda x: sum(x.isnull()))
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LabelencoderX=LabelEncoder()

# %%
BFTrain.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
BFTrain["Product_ID"]=LabelencoderX.fit_transform(BFTrain.iloc[:,1].values)

# %%
BFTrain
# Out:
#         User_ID  Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001         672      F   0-17          10             A
# 1       1000001        2376      F   0-17          10             A
# 2       1000001         852      F   0-17          10             A
# 3       1000001         828      F   0-17          10             A
# 4       1000002        2734      M    55+          16             C
# ...         ...         ...    ...    ...         ...           ...
# 550063  1006033        3567      M  51-55          13             B
# 550064  1006035        3568      F  26-35           1             C
# 550065  1006036        3568      F  26-35          15             B
# 550066  1006038        3568      F    55+           1             C
# 550067  1006039        3566      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
BFTrain["Gender"]=LabelencoderX.fit_transform(BFTrain.iloc[:,2].values)
BFTrain
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation City_Category  \
# 0       1000001         672       0   0-17          10             A
# 1       1000001        2376       0   0-17          10             A
# 2       1000001         852       0   0-17          10             A
# 3       1000001         828       0   0-17          10             A
# 4       1000002        2734       1    55+          16             C
# ...         ...         ...     ...    ...         ...           ...
# 550063  1006033        3567       1  51-55          13             B
# 550064  1006035        3568       0  26-35           1             C
# 550065  1006036        3568       0  26-35          15             B
# 550066  1006038        3568       0    55+           1             C
# 550067  1006039        3566       0  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
BFTrain["City_Category"]=LabelencoderX.fit_transform(BFTrain.iloc[:,5].values)

# %%
BFTrain["Stay_In_Current_City_Years"]=LabelencoderX.fit_transform(BFTrain.iloc[:,6].values)

# %%
BFTrain.dtypes
# Out:
# User_ID                         int64
# Product_ID                      int64
# Gender                          int64
# Age                            object
# Occupation                      int64
# City_Category                   int64
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
BFTrain.Age.value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
BFTAge=BFTrain.Age.replace({'0-17':0, '18-25':1, '26-35':2, '36-45':3, '46-50':4, '51-55':5, '55+':6})

# %%
BFTAge.value_counts()
# Out:
# 2    219587
# 3    110013
# 1     99660
# 4     45701
# 5     38501
# 6     21504
# 0     15102
# Name: Age, dtype: int64

# %%
BFTrain[['Age']]=BFTAge
BFTrain
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000001         672       0    0          10              0
# 1       1000001        2376       0    0          10              0
# 2       1000001         852       0    0          10              0
# 3       1000001         828       0    0          10              0
# 4       1000002        2734       1    6          16              2
# ...         ...         ...     ...  ...         ...            ...
# 550063  1006033        3567       1    5          13              1
# 550064  1006035        3568       0    2           1              2
# 550065  1006036        3568       0    2          15              1
# 550066  1006038        3568       0    6           1              2
# 550067  1006039        3566       0    4           0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# ...

# %%
BFTrain.dtypes
# Out:
# User_ID                         int64
# Product_ID                      int64
# Gender                          int64
# Age                             int64
# Occupation                      int64
# City_Category                   int64
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
X_Train=BFTrain.iloc[:,0:11]
Y_Train=BFTrain.iloc[:,-1]

# %%
X_Train
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000001         672       0    0          10              0
# 1       1000001        2376       0    0          10              0
# 2       1000001         852       0    0          10              0
# 3       1000001         828       0    0          10              0
# 4       1000002        2734       1    6          16              2
# ...         ...         ...     ...  ...         ...            ...
# 550063  1006033        3567       1    5          13              1
# 550064  1006035        3568       0    2           1              2
# 550065  1006036        3568       0    2          15              1
# 550066  1006038        3568       0    6           1              2
# 550067  1006039        3566       0    4           0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# ...

# %%
pd.DataFrame(Y_Train)
# Out:
#         Purchase
# 0           8370
# 1          15200
# 2           1422
# 3           1057
# 4           7969
# ...          ...
# 550063       368
# 550064       371
# 550065       137
# 550066       365
# 550067       490
#
# [550068 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
Regressor=LinearRegression()
Regressor.fit(X_Train, Y_Train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
BFTest
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
BFTest.apply(lambda x:sum(x.isnull()))
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
BFTest['Product_Category_2']=BFTest.Product_Category_2.fillna(BFTest.Product_Category_2.mean())
BFTest['Product_Category_3']=BFTest.Product_Category_3.fillna(BFTest.Product_Category_3.mean())

# %%
BFTest.apply(lambda x: sum(x.isnull()))
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# dtype: int64

# %%
BFTest.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
BFTest["Product_ID"]=LabelencoderX.fit_transform(BFTest.iloc[:,1].values)
BFTest["Gender"]=LabelencoderX.fit_transform(BFTest.iloc[:,2].values)
BFTest["City_Category"]=LabelencoderX.fit_transform(BFTest.iloc[:,5].values)
BFTest["Stay_In_Current_City_Years"]=LabelencoderX.fit_transform(BFTest.iloc[:,6].values)

# %%
BFTestAge=BFTest.Age.replace({'0-17':0, '18-25':1, '26-35':2, '36-45':3, '46-50':4, '51-55':5, '55+':6})

# %%
BFTest[["Age"]]=BFTestAge

# %%
BFTest.dtypes
# Out:
# User_ID                         int64
# Product_ID                      int64
# Gender                          int64
# Age                             int64
# Occupation                      int64
# City_Category                   int64
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
X_Test=BFTest

# %%
Y_Pred=Regressor.predict(X_Test)
Y_Pred
# Out:
# array([11389.12380332, 11394.50242021,  8193.87562773, ...,
#        11592.4354604 ,  7305.76814578,  9463.17959915])

# %%
SampSub=pd.read_csv("/Users/shankarraja/Downloads/Data Science/Ampersand Academy/BlackFriday/BlackFridaySampleSub.csv")

# %%
SampSub
# Out:
#         Purchase  User_ID Product_ID
# 0            100  1000004  P00128942
# 1            100  1000009  P00113442
# 2            100  1000010  P00288442
# 3            100  1000010  P00145342
# 4            100  1000011  P00053842
# ...          ...      ...        ...
# 233594       100  1006036  P00118942
# 233595       100  1006036  P00254642
# 233596       100  1006036  P00031842
# 233597       100  1006037  P00124742
# 233598       100  1006039  P00316642
#
# [233599 rows x 3 columns]

# %%
SampSub['Purchase']=Y_Pred
SampSub
# Out:
#             Purchase  User_ID Product_ID
# 0       11389.123803  1000004  P00128942
# 1       11394.502420  1000009  P00113442
# 2        8193.875628  1000010  P00288442
# 3        9628.696221  1000010  P00145342
# 4       10521.359352  1000011  P00053842
# ...              ...      ...        ...
# 233594   8111.198404  1006036  P00118942
# 233595   8904.411529  1006036  P00254642
# 233596  11592.435460  1006036  P00031842
# 233597   7305.768146  1006037  P00124742
# 233598   9463.179599  1006039  P00316642
#
# [233599 rows x 3 columns]
